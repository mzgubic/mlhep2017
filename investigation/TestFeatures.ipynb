# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/DS_2_train_brick98_Tracking2Added.csv')

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1    index  event_id             X  \
# 0               0             1        1      -999  43900.445312
# 1               1            71       71      -999  58495.214844
# 2               2           136      136      -999  50601.484375
# 3               3           300      300      -999  53538.218750
# 4               4           301      301      -999  47908.476562
# 5               5           435      435      -999  59247.718750
# 6               6           504      504      -999  66286.382812
# 7               7           531      531      -999  55336.324219
# 8               8           603      603      -999  42316.585938
# 9               9           765      765      -999  44979.679688
# 10             10           858      858      -999  54341.328125
# 11             11          1062     1062      -999  62567.765625
# 12             12          1304     1304      -999  51092.500000
# ...

# %%
sig = df[df.signal == 1]
bkg = df[df.signal == 0]

# %%
fig, ax = plt.subplots(1, figsize=(15, 8))
ax.hist(bkg.cyl1, alpha=0.5, bins=20, normed=True)
ax.hist(sig.cyl1, alpha=0.5, bins=20, normed=True)
#ax.set_yscale('log')
plt.show()
